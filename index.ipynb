# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
html_page = requests.get('https://www.residentadvisor.net/events/es/ibiza') 
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
events_etc=soup.find('div',id='event-listing')
events=events_etc.findAll('li')
events[1].find('a',itemprop="url").text
# Out:
# "Resistance Ibiza Week 2 - Carl's Birthday"

# %%
events[2].findAll('a')[-1].text
# Out:
# 'Hï Ibiza'

# %%
events[0].find('p', class_='eventDate').text[:-2]
# Out:
# 'Tue, 30 Jul 2019'

# %%
type(events[5].find('p',class_='attending'))
# Out:
# NoneType

# %%
def scrape_events(events_page_url):
    event_names=[]
    venues=[]
    event_dates=[]
    numbers_of_attendees=[]
    html_page=requests.get(events_page_url)
    soup=BeautifulSoup(html_page.content,'html.parser')
    events_etc=soup.find('div',id='event-listing')
    events=events_etc.findAll('li')
    for i in range(len(events)):
        date_or_not=events[i].findAll('p', class_='eventDate')
        if len(date_or_not)==1:
            event_date=events[i].find('p', class_='eventDate').text[:-2]
        else:
            end_of_events=events[i].find('div',class_='but myra mt16')
            if end_of_events:
                pass
            else:
                event_name=events[i].find('a',itemprop="url").text
                venue=events[i].findAll('a')[-1].text
                attending=events[i].findAll('p',class_='attending')
                if len(attending)==0:
                    number_of_attendees=float('NaN')
                else:
                    number_of_attendees=attending[0].text.split()[0]
                event_dates.append(event_date)
                event_names.append(event_name)
                venues.append(venue)
                numbers_of_attendees.append(number_of_attendees)
          
    df=pd.DataFrame([event_names,venues,event_dates,numbers_of_attendees]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
scrape_events('https://www.residentadvisor.net/events/es/ibiza')
# Out:
#                                             Event_Name  \
# 0            Resistance Ibiza Week 2 - Carl's Birthday
# 1                                            BODYWORKS
# 2    The Ritual with Anané & Louie Vega at Heart Fa...
# 3      Tomorrowland presents Dimitri Vegas & Like Mike
# 4                                               Шпагат
# 5                         Craig David's TS5 Pool Party
# 6                                             Kisstory
# 7                                       Diplo & Anitta
# 8                         Together - Season 9 - Week 9
# 9                                 Flesh Label Showcase
# 10                          Oceanbeat Ibiza Boat Party
# 11   Float Your Boat Tuesdays - The Boat That Gets ...
# 12   Loulou Records presents Music Please #3 at B12...
# 13                        Keep On Dancing On the Beach
# 14                   Freakn Trouvé presents Undercolor
# 15                Pukka Up - Tuesday Sunset Boat Party
# 16                                            Paradise
# 17   Lost In Ibiza Boat Party Jamie Jones' Paradise...
# 18                   The Gardenarium - Elrow x Absolut
# 19                          Terminal4 X Tronic Week 11
# 20                                        Dance or Die
# 21   Armin van Buuren and Sunnery James & Ryan Marc...
# 22                          Steve Aoki Neon Future III
# 23                                        Flower Power
# 24                          Oceanbeat Ibiza Boat Party
# 25           Cirque de la Nuit Ibiza Pool & Boat Party
# 26                                        Bongos Bingo
# 27                    Brasilio presents La Troya Ibiza
# 28                                             HotBed
# 29                       Fiesta del Agua | Water Party
# ..                                                 ...
# 86                                            Toolroom
# 87                                             WooMooN
# 88                Bedouin presents Saga at Heart Ibiza
# 89                    Apollonia presents Planet Claire
# 90                                        Rumors Ibiza
# 91                                          Glitterbox
# 92                                       Soild Grooves
# 93                                The Zoo Project 2019
# 94                                         Sin Sundays
# 95           Cirque de la Nuit Ibiza Pool & Boat Party
# 96                                           La Espuma
# 97                          Oceanbeat Ibiza Boat Party
# 98                                         MUCHO IBIZA
# 99                                            Warriors
# 100                                   Pikes On Sundays
# 101                                    Circoloco Ibiza
# 102                      Cocoon Ibiza 20th Anniversary
# 103                         The Masquerade by Claptone
# 104  Heart Ibiza & Bob Sinclar present Electrico Ro...
# 105                                BIG by David Guetta
# 106                    Flesh Label Showcase @OD Skybar
# 107                                          Hed Kandi
# 108                              Radio 1 Dance Anthems
# 109                                         Wax Da Jam
# 110                         Oceanbeat Ibiza Boat Party
# 111                                            Mansion
# 112                              GLOW Neon Paint Party
# 113  Float Your Boat Monday Sunset with any day Ibi...
# 114                                          One Third
# 115                                          RICHBITCH
#
#                       Venue        Event_Date Number_of_Attendees
# 0                 Privilege  Tue, 30 Jul 2019                 225
# 1                  Hï Ibiza  Tue, 30 Jul 2019                  14
# 2               Heart Ibiza  Tue, 30 Jul 2019                   8
# 3       Ushuaïa Beach Hotel  Tue, 30 Jul 2019                   7
# 4         Ibiza Underground  Tue, 30 Jul 2019                 NaN
# 5         Ibiza Rocks Hotel  Tue, 30 Jul 2019                 NaN
# 6               Ocean Beach  Tue, 30 Jul 2019                 NaN
# 7               Pacha Ibiza  Tue, 30 Jul 2019                 NaN
# 8                   Amnesia  Tue, 30 Jul 2019                 NaN
# 9          Folys Cafe Ibiza  Tue, 30 Jul 2019                 NaN
# 10           Oceanbeat Pier  Tue, 30 Jul 2019                 NaN
# 11         San Antonio Port  Tue, 30 Jul 2019                 NaN
# 12         Tantra Bar Ibiza  Tue, 30 Jul 2019                 NaN
# 13                Bora Bora  Tue, 30 Jul 2019                 NaN
# 14                     Eden  Tue, 30 Jul 2019                 NaN
# 15                Rio Ibiza  Tue, 30 Jul 2019                 NaN
# 16                    DC-10  Wed, 31 Jul 2019                 441
# 17   Boat - Captain Nemo II  Wed, 31 Jul 2019                  39
# 18               Cova Santa  Wed, 31 Jul 2019                  22
# 19                     Eden  Wed, 31 Jul 2019                  10
# 20      Ushuaïa Beach Hotel  Wed, 31 Jul 2019                 NaN
# 21                 Hï Ibiza  Wed, 31 Jul 2019                 NaN
# 22                  Amnesia  Wed, 31 Jul 2019                 NaN
# 23              Pacha Ibiza  Wed, 31 Jul 2019                 NaN
# 24           Oceanbeat Pier  Wed, 31 Jul 2019                 NaN
# 25          Ibiza Boat Club  Wed, 31 Jul 2019                 NaN
# 26        Ibiza Rocks Hotel  Wed, 31 Jul 2019                 NaN
# 27              Heart Ibiza  Wed, 31 Jul 2019                 NaN
# 28              Ocean Beach  Wed, 31 Jul 2019                 NaN
# 29               Es Paradis  Wed, 31 Jul 2019                 NaN
# ..                      ...               ...                 ...
# 86                     Eden  Sun, 04 Aug 2019                  17
# 87               Cova Santa  Sun, 04 Aug 2019                  15
# 88              Heart Ibiza  Sun, 04 Aug 2019                  14
# 89              Octan Ibiza  Sun, 04 Aug 2019                 NaN
# 90         Las Dalias Ibiza  Sun, 04 Aug 2019                 NaN
# 91                 Hï Ibiza  Sun, 04 Aug 2019                 NaN
# 92               Vista Club  Sun, 04 Aug 2019                 NaN
# 93           Benimussa Park  Sun, 04 Aug 2019                 NaN
# 94              Ocean Beach  Sun, 04 Aug 2019                 NaN
# 95          Ibiza Boat Club  Sun, 04 Aug 2019                 NaN
# 96                  Amnesia  Sun, 04 Aug 2019                 NaN
# 97           Oceanbeat Pier  Sun, 04 Aug 2019                 NaN
# 98      Ushuaïa Beach Hotel  Sun, 04 Aug 2019                 NaN
# 99              Octan Ibiza  Sun, 04 Aug 2019                 NaN
# 100             Pikes Ibiza  Sun, 04 Aug 2019                 NaN
# 101                   DC-10  Mon, 05 Aug 2019                 364
# 102                 Amnesia  Mon, 05 Aug 2019                  34
# 103             Pacha Ibiza  Mon, 05 Aug 2019                  15
# 104             Heart Ibiza  Mon, 05 Aug 2019                   6
# 105     Ushuaïa Beach Hotel  Mon, 05 Aug 2019                 NaN
# 106       Ocean Drive Hotel  Mon, 05 Aug 2019                 NaN
# 107             Ocean Beach  Mon, 05 Aug 2019                 NaN
# 108       Ibiza Rocks Hotel  Mon, 05 Aug 2019                 NaN
# 109             Pikes Ibiza  Mon, 05 Aug 2019                 NaN
# 110          Oceanbeat Pier  Mon, 05 Aug 2019                 NaN
# 111                    Eden  Mon, 05 Aug 2019                 NaN
# 112              Es Paradis  Mon, 05 Aug 2019                 NaN
# 113        San Antonio Port  Mon, 05 Aug 2019                 NaN
# 114              Vista Club  Mon, 05 Aug 2019                 NaN
# 115                Hï Ibiza  Mon, 05 Aug 2019                 NaN
#
# [116 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
url='https://www.residentadvisor.net/events/es/ibiza'
base_url='https://www.residentadvisor.net/
more_pages=soup.find('div',id='previous-next')
next_page=more_pages.findAll('a')[-1]
next_page.attrs['href']
# Out:
# '/events/es/ibiza/week/2019-08-06'

# %%
def next_page(url):
    base_url='https://www.residentadvisor.net'
    html_page=requests.get(url)
    soup=BeautifulSoup(html_page.content,'html.parser')
    more_pages=soup.find('div',id='previous-next')
    next_page=more_pages.findAll('a')[-1]
    next_page_url=base_url+next_page.attrs['href']
    return next_page_url
next_page('https://www.residentadvisor.net/events/es/ibiza')
# Out:
# 'https://www.residentadvisor.net/events/es/ibiza/week/2019-08-06'

# %%
next_page('https://www.residentadvisor.net/events/es/ibiza/week/2019-08-06')
# Out:
# 'https://www.residentadvisor.net/events/es/ibiza/week/2019-08-13'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
current_page='https://www.residentadvisor.net/events/es/ibiza'
df=scrape_events(current_page)
number_of_events=len(df)
number_of_pages=1
while number_of_events<1000:
    current_page=next_page(current_page)
    print(current_page)
    next_df=scrape_events(current_page)
    df=pd.concat([df,next_df],ignore_index=True)
    number_of_events=len(df)
    number_of_pages+=1
# Out:
# https://www.residentadvisor.net/events/es/ibiza/week/2019-08-06
# https://www.residentadvisor.net/events/es/ibiza/week/2019-08-13
# https://www.residentadvisor.net/events/es/ibiza/week/2019-08-20
# https://www.residentadvisor.net/events/es/ibiza/week/2019-08-27
# https://www.residentadvisor.net/events/es/ibiza/week/2019-09-03
# https://www.residentadvisor.net/events/es/ibiza/week/2019-09-10
# https://www.residentadvisor.net/events/es/ibiza/week/2019-09-17
# https://www.residentadvisor.net/events/es/ibiza/week/2019-09-24
# https://www.residentadvisor.net/events/es/ibiza/week/2019-10-01
# https://www.residentadvisor.net/events/es/ibiza/week/2019-10-08
# https://www.residentadvisor.net/events/es/ibiza/week/2019-10-15
# https://www.residentadvisor.net/events/es/ibiza/week/2019-10-22
# https://www.residentadvisor.net/events/es/ibiza/week/2019-10-29
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-bd2262967f1a> in <module>
#       4 number_of_pages=1
#       5 while number_of_events<1000:
# ----> 6     current_page=next_page(current_page)
#       7     print(current_page)
#       8     next_df=scrape_events(current_page)
#
# <ipython-input-163-20035b881d7a> in next_page(url)
#       5     more_pages=soup.find('div',id='previous-next')
#       6     next_page=more_pages.findAll('a')[-1]
# ----> 7     next_page_url=base_url+next_page.attrs['href']
#       8     return next_page_url
#       9 next_page('https://www.residentadvisor.net/events/es/ibiza')
#
# KeyError: 'href'

# %%
df.sort_values(['Number_of_Attendees','Event_Date'],ascending=False)
# Out:
#                                             Event_Name  \
# 349                                           Paradise
# 31                                           Afterlife
# 323                                    Circoloco Ibiza
# 352                                      Boris Brejcha
# 133  Lost In Ibiza Boat Party Jamie Jones' Paradise...
# 817  House Of Silk Meets Garage Nation ( Ibiza Clos...
# 149  Lost In Ibiza Boat Party Jamie Jones' Paradise...
# 150               Storytellers presents: Mayan Warrior
# 565                            ABODE Thursdays Amnesia
# 777                                         Glitterbox
# 309                   Apollonia presents Planet Claire
# 695                                         Glitterbox
# 613               Bedouin presents Saga at Heart Ibiza
# 505                                               ANTS
# 399                                               ANTS
# 759                                               ANTS
# 760                                        Elrow Ibiza
# 292                                       Black Coffee
# 325                    MK’S Area 10 Closing Pool Party
# 326                         The Masquerade by Claptone
# 486                                       Transmoderna
# 275                                     Defected Ibiza
# 667                                       Transmoderna
# 897        Music On Ibiza at Pacha Closing Party Day 2
# 164  Lost In Ibiza Boat Party Jamie Jones' Paradise...
# 578                                       Transmoderna
# 804                                           Paradise
# 116  Resistance Ibiza Week 3 - Adam Beyer presents ...
# 338                            Resistance Ibiza Week 5
# 870                             Paradise Closing Party
# ..                                                 ...
# 174          Cirque de la Nuit Ibiza Pool & Boat Party
# 175                                                DNS
# 176                         37th Anniversary Bora Bora
# 177                                       Urban Policy
# 178                                      Denial Island
# 179                                        SuperMartXé
# 180                           Homies Freedonia Edition
# 584                         Oceanbeat Ibiza Boat Party
# 585                                      Denial Island
# 586              Cuckoo Land Pool Party with Disciples
# 587  B!crazy Ibiza with Jean Claude Ades • Jeremy O...
# 588                            Captured Festival Day 1
# 589                            Agoria presents 'Drift'
# 590                                  Captured Festival
# 591                                         Pool Party
# 592                                         Melon Bomb
# 593                                       Urban Policy
# 594                                F*** ME I'M FAMOUS!
# 595                                        SuperMartXé
# 886                        SuperMartXé - Closing Party
# 58                             Agoria presents 'DRIFT'
# 59                                 F*** ME I'M FAMOUS!
# 60                                          Melon Bomb
# 61                          Oceanbeat Ibiza Boat Party
# 62                                          Pool Party
# 63                                       Denial Island
# 64           Cirque de la Nuit Ibiza Pool & Boat Party
# 65                                        Urban Policy
# 66                                        Mirage Ibiza
# 67       [CANCELLED] Cuckoo Land presents Sonny Fodera
#
#                       Venue        Event_Date Number_of_Attendees
# 349                   DC-10  Wed, 21 Aug 2019                  92
# 31                 Hï Ibiza  Thu, 01 Aug 2019                  92
# 323                   DC-10  Mon, 19 Aug 2019                  92
# 352                Hï Ibiza  Wed, 21 Aug 2019                   9
# 133  Boat - Captain Nemo II  Wed, 07 Aug 2019                   9
# 817                    Eden  Thu, 26 Sep 2019                   9
# 149  Boat - Captain Nemo II  Thu, 08 Aug 2019                   9
# 150              Cova Santa  Thu, 08 Aug 2019                   9
# 565                 Amnesia  Thu, 05 Sep 2019                   9
# 777                Hï Ibiza  Sun, 22 Sep 2019                   9
# 309             Octan Ibiza  Sun, 18 Aug 2019                   9
# 695                Hï Ibiza  Sun, 15 Sep 2019                   9
# 613             Heart Ibiza  Sun, 08 Sep 2019                   9
# 505     Ushuaïa Beach Hotel  Sat, 31 Aug 2019                   9
# 399     Ushuaïa Beach Hotel  Sat, 24 Aug 2019                   9
# 759     Ushuaïa Beach Hotel  Sat, 21 Sep 2019                   9
# 760                 Amnesia  Sat, 21 Sep 2019                   9
# 292                Hï Ibiza  Sat, 17 Aug 2019                   9
# 325       Ibiza Rocks Hotel  Mon, 19 Aug 2019                   9
# 326             Pacha Ibiza  Mon, 19 Aug 2019                   9
# 486             Pacha Ibiza  Fri, 30 Aug 2019                   9
# 275                    Eden  Fri, 16 Aug 2019                   9
# 667             Pacha Ibiza  Fri, 13 Sep 2019                   9
# 897             Pacha Ibiza  Fri, 11 Oct 2019                   9
# 164  Boat - Captain Nemo II  Fri, 09 Aug 2019                   9
# 578             Pacha Ibiza  Fri, 06 Sep 2019                   9
# 804                   DC-10  Wed, 25 Sep 2019                  89
# 116               Privilege  Tue, 06 Aug 2019                  87
# 338               Privilege  Tue, 20 Aug 2019                  86
# 870                   DC-10  Wed, 02 Oct 2019                  80
# ..                      ...               ...                 ...
# 174         Ibiza Boat Club  Fri, 09 Aug 2019                 NaN
# 175       Ibiza Rocks Hotel  Fri, 09 Aug 2019                 NaN
# 176               Bora Bora  Fri, 09 Aug 2019                 NaN
# 177              Es Paradis  Fri, 09 Aug 2019                 NaN
# 178           Destino Ibiza  Fri, 09 Aug 2019                 NaN
# 179               Privilege  Fri, 09 Aug 2019                 NaN
# 180             Pikes Ibiza  Fri, 09 Aug 2019                 NaN
# 584          Oceanbeat Pier  Fri, 06 Sep 2019                 NaN
# 585           Destino Ibiza  Fri, 06 Sep 2019                 NaN
# 586       Ibiza Rocks Hotel  Fri, 06 Sep 2019                 NaN
# 587             Heart Ibiza  Fri, 06 Sep 2019                 NaN
# 588          Benimussa Park  Fri, 06 Sep 2019                 NaN
# 589       Blue Marlin Ibiza  Fri, 06 Sep 2019                 NaN
# 590          Benimussa Park  Fri, 06 Sep 2019                 NaN
# 591             Ocean Beach  Fri, 06 Sep 2019                 NaN
# 592             Pikes Ibiza  Fri, 06 Sep 2019                 NaN
# 593              Es Paradis  Fri, 06 Sep 2019                 NaN
# 594                Hï Ibiza  Fri, 06 Sep 2019                 NaN
# 595               Privilege  Fri, 06 Sep 2019                 NaN
# 886               Privilege  Fri, 04 Oct 2019                 NaN
# 58        Blue Marlin Ibiza  Fri, 02 Aug 2019                 NaN
# 59                 Hï Ibiza  Fri, 02 Aug 2019                 NaN
# 60              Pikes Ibiza  Fri, 02 Aug 2019                 NaN
# 61           Oceanbeat Pier  Fri, 02 Aug 2019                 NaN
# 62              Ocean Beach  Fri, 02 Aug 2019                 NaN
# 63            Destino Ibiza  Fri, 02 Aug 2019                 NaN
# 64          Ibiza Boat Club  Fri, 02 Aug 2019                 NaN
# 65               Es Paradis  Fri, 02 Aug 2019                 NaN
# 66           Benimussa Park  Fri, 02 Aug 2019                 NaN
# 67        Ibiza Rocks Hotel  Fri, 02 Aug 2019                 NaN
#
# [907 rows x 4 columns]

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
